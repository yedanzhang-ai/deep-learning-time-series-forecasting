# %%
# Copy your GitHub package into the working directory
# !cp -r /kaggle/input/deep-learning-forecasting-package/* /kaggle/working/

# Make the src directory importable
import sys, os
sys.path.append("/kaggle/working/src")

os.listdir("/kaggle/working")
# Out:
# ['data', 'requirements.txt', 'config', 'src', '__notebook__.ipynb']

# %%
# Install any extra Python packages (Darts, PL, Optuna, etc.)
# !pip install -q -r /kaggle/input/deep-learning-forecasting-package/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 95.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 46.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 122.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.6/917.6 kB 47.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.3/802.3 kB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.4 MB/s eta 0:00:00
# ...

# %%
# !python /kaggle/working/src/ts_dl_forecasting/preprocess_raw_data.py --config config/raw_data.yaml
# Out:
# Preprocessing complete.

# %%
# !python /kaggle/working/src/ts_dl_forecasting/feature_engineering.py --config config/feature_engineering.yaml
# Out:
# Feature Engineering complete.

# %%
from ts_dl_forecasting.pipeline import run_experiment

lstm_results = run_experiment("config/experiment_lstm.yaml")
# Out:
# [I 2025-12-02 01:36:11,955] A new study created in memory with name: no-name-db0b6d2d-a9c1-4aeb-90c9-56daaba8f617
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 01:36:56,261] Trial 0 finished with value: 97.94661712646484 and parameters: {'lookback': 365, 'hidden': 128, 'layers': 3, 'dropout': 0.23704996731841335, 'batch': 128, 'lr': 0.00038981883336987, 'weight_decay': 1.1167700664770882e-06}. Best is trial 0 with value: 97.94661712646484.
# [I 2025-12-02 01:37:19,328] Trial 1 finished with value: 88.17072296142578 and parameters: {'lookback': 365, 'hidden': 512, 'layers': 2, 'dropout': 0.21639137726669466, 'batch': 64, 'lr': 0.0007995287932966629, 'weight_decay': 4.914753522172465e-05}. Best is trial 1 with value: 88.17072296142578.
# ...

# %%
gru_results = run_experiment("config/experiment_gru.yaml")
# Out:
# [I 2025-12-02 01:42:38,850] A new study created in memory with name: no-name-41527586-f84e-43f3-816d-ec8dea0b468c
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 01:43:04,426] Trial 0 finished with value: 96.37574005126953 and parameters: {'lookback': 365, 'hidden': 128, 'layers': 3, 'dropout': 0.23704996731841335, 'batch': 128, 'lr': 0.00038981883336987, 'weight_decay': 1.1167700664770882e-06}. Best is trial 0 with value: 96.37574005126953.
# [I 2025-12-02 01:43:24,315] Trial 1 finished with value: 92.40289306640625 and parameters: {'lookback': 365, 'hidden': 512, 'layers': 2, 'dropout': 0.21639137726669466, 'batch': 64, 'lr': 0.0007995287932966629, 'weight_decay': 4.914753522172465e-05}. Best is trial 1 with value: 92.40289306640625.
# ...

# %%
nbeats_results = run_experiment("config/experiment_nbeats.yaml")
# Out:
# [I 2025-12-02 01:48:12,020] A new study created in memory with name: no-name-d27fe2ff-e702-4778-b00f-30aa35f8fe87
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 01:49:10,421] Trial 0 finished with value: 89.38939666748047 and parameters: {'lookback': 365, 'stacks': 6, 'blocks': 3, 'width': 1024, 'dropout': 0.1835461847943926, 'batch': 32, 'lr': 0.0003621213143341041, 'weight_decay': 3.2999312639278077e-06}. Best is trial 0 with value: 89.38939666748047.
# [I 2025-12-02 01:49:14,249] Trial 1 finished with value: 63.14710998535156 and parameters: {'lookback': 90, 'stacks': 8, 'blocks': 3, 'width': 512, 'dropout': 0.3708502325615195, 'batch': 32, 'lr': 0.00045020561009688037, 'weight_decay': 1.3052134028401253e-05}. Best is trial 1 with value: 63.14710998535156.
# ...

# %%
tcn_results = run_experiment("config/experiment_tcn.yaml")
# Out:
# [I 2025-12-02 01:54:14,657] A new study created in memory with name: no-name-8d6f518a-c2e4-400e-b9b7-a57872e295f3
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 01:55:31,851] Trial 0 finished with value: 100.37747192382812 and parameters: {'lookback': 365, 'filters': 128, 'kernel': 5, 'dilation_base': 3, 'dropout': 0.30287647059403944, 'batch': 32, 'lr': 0.00018165712933787686, 'weight_decay': 6.763981234000725e-06}. Best is trial 0 with value: 100.37747192382812.
# [I 2025-12-02 01:55:34,360] Trial 1 finished with value: 99.851318359375 and parameters: {'lookback': 60, 'filters': 128, 'kernel': 7, 'dilation_base': 3, 'dropout': 0.21339821239866677, 'batch': 64, 'lr': 0.00022991365366036416, 'weight_decay': 2.8190904456231543e-06}. Best is trial 1 with value: 99.851318359375.
# ...

# %%
tft_results = run_experiment("config/experiment_tft.yaml")
# Out:
# [I 2025-12-02 02:05:55,858] A new study created in memory with name: no-name-9f83da9d-2d49-40ba-bda9-177045642bfb
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 02:12:31,589] Trial 0 finished with value: 66.0198974609375 and parameters: {'lookback': 365, 'hidden': 64, 'lstm_layers': 1, 'heads': 4, 'dropout': 0.30287647059403944, 'batch': 32, 'lr': 0.00018165712933787686, 'weight_decay': 6.763981234000725e-06}. Best is trial 0 with value: 66.0198974609375.
# [I 2025-12-02 02:12:36,103] Trial 1 finished with value: 73.50489807128906 and parameters: {'lookback': 60, 'hidden': 64, 'lstm_layers': 4, 'heads': 4, 'dropout': 0.21339821239866677, 'batch': 64, 'lr': 0.00022991365366036416, 'weight_decay': 2.8190904456231543e-06}. Best is trial 0 with value: 66.0198974609375.
# ...

# %%
tide_results = run_experiment("config/experiment_tide.yaml")
# Out:
# [I 2025-12-02 02:57:51,869] A new study created in memory with name: no-name-819726cb-7753-4c60-80b5-d5c89b2890f0
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 02:58:16,491] Trial 0 finished with value: 75.47650909423828 and parameters: {'lookback': 365, 'hidden': 64, 'encoder_layers': 1, 'decoder_layers': 4, 'decoder_dim': 32, 'temporal_width': 2, 'dropout': 0.22453035910302094, 'batch': 64, 'lr': 0.00014350523310597898, 'weight_decay': 1.2282818545944522e-05}. Best is trial 0 with value: 75.47650909423828.
# [I 2025-12-02 02:58:22,154] Trial 1 finished with value: 72.2318115234375 and parameters: {'lookback': 365, 'hidden': 64, 'encoder_layers': 1, 'decoder_layers': 1, 'decoder_dim': 128, 'temporal_width': 6, 'dropout': 0.23730591979689342, 'batch': 32, 'lr': 0.00018966076878299475, 'weight_decay': 8.114170909427843e-06}. Best is trial 1 with value: 72.2318115234375.
# ...

# %%
# !PYTHONPATH=/kaggle/working/src python -m ts_dl_forecasting.cli \
    --batch config/experiments_batch.yaml \
    --report \
    --output-root outputs \
    --plot-path outputs/all_models_vs_actual.png
# Out:
# INFO:__main__:Running batch experiments from: config/experiments_batch.yaml
# INFO:__main__:  → Running experiment for model: lstm (config/experiment_lstm.yaml)
# INFO:ts_dl_forecasting.pipeline:Running experiment for model 'lstm'
# INFO:ts_dl_forecasting.pipeline:  data_config:  config/data.yaml
# INFO:ts_dl_forecasting.pipeline:  model_config: config/model_lstm.yaml
# INFO:ts_dl_forecasting.pipeline:  output_dir:   outputs/lstm
# INFO:ts_dl_forecasting.data:Loading data from data/feature_engineering/sales_forecast_features.csv
# INFO:ts_dl_forecasting.data:Total length: 1941 | train_end: 1521 | valid_end: 1843
# INFO:ts_dl_forecasting.data:Using StandardScaler for model lstm
# INFO:ts_dl_forecasting.data:Using StandardScaler for model lstm
# INFO:ts_dl_forecasting.pipeline:Starting hyperparameter tuning with Optuna ...
# [I 2025-12-02 03:00:42,825] A new study created in memory with name: no-name-2fcb9871-2a0e-4d35-914a-b7be35b26479
# ...
